# %% [markdown]
# Assignment -2 Pandas

# %% [markdown]
# Q1. List any five functions of the pandas library with execution.

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
pd.Categorical(df)
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', ..., 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']
# Length: 12
# Categories (12, object): ['Age', 'Cabin', 'Embarked', 'Fare', ..., 'Sex', 'SibSp', 'Survived', 'Ticket']

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %% [markdown]
# Q2. Given a Pandas DataFrame df with columns 'A', 'B', and 'C', write a Python function to re-index the
# DataFrame with a new index that starts from 1 and increments by 2 for each row.

# %%
data = {
    
    'A':['shiv modi','king','Dhruv','jig','hii'],
    'B':[0,1,2,3,4],
    'C':[3,1,2,4,5]
}

# %%
len(data)
# Out:
# 3

# %%
df1 = pd.DataFrame(data)

# %%
data1 = []

x = len(data)

for i in range(x):
    i = i + i
    data1.append(i)

# %%
data1
# Out:
# [0, 2, 4]

# %%
df1.columns  = data1

# %%
df1
# Out:
#            0  2  4
# 0  shiv modi  0  3
# 1       king  1  1
# 2      Dhruv  2  2
# 3        jig  3  4
# 4        hii  4  5

# %% [markdown]
# Q-3 ) You have a Pandas DataFrame df with a column named 'Values'. Write a Python function that
# iterates over the DataFrame and calculates the sum of the first three values in the 'Values' column. The
# function should print the sum to the console.

# %%
df1['values'] = [10, 20, 30, 40, 50]

# %%
df1
# Out:
#            0  2  4  values
# 0  shiv modi  0  3      10
# 1       king  1  1      20
# 2      Dhruv  2  2      30
# 3        jig  3  4      40
# 4        hii  4  5      50

# %%
sum(df1[0:3]['values'].values)
# Out:
# 60

# %% [markdown]
# Q4.Given a Pandas DataFrame df with a column 'Text', write a Python function to create a new column
# 'Word_Count' that contains the number of words in each row of the 'Text' column.

# %%
df1['Text'] = df1[0]

# %%
df1
# Out:
#            0  2  4  values       Text
# 0  shiv modi  0  3      10  shiv modi
# 1       king  1  1      20       king
# 2      Dhruv  2  2      30      Dhruv
# 3        jig  3  4      40        jig
# 4        hii  4  5      50        hii

# %%
words = df1['Text'].str.split().str.len()

# %%
df1['Word_Count'] = words

# %%
df1
# Out:
#            0  2  4  values       Text  Word_Count
# 0  shiv modi  0  3      10  shiv modi           2
# 1       king  1  1      20       king           1
# 2      Dhruv  2  2      30      Dhruv           1
# 3        jig  3  4      40        jig           1
# 4        hii  4  5      50        hii           1

# %% [markdown]
# Q-5) How are DataFrame.size() and DataFrame.shape() different?

# %% [markdown]
# 1) return the number of elements in dataframe code : datafram.size() ,
#
# for ex : df1.size()
#
# 2) return a tupple represnting dimensionality of the DataFrame
#
# for ex : df1.shape

# %% [markdown]
# Q6. Which function of pandas do we use to read an excel file?

# %%
pd.read_excel 

# we used read_excel function to read excel file
# Out:
# <function pandas.io.excel._base.read_excel(io, sheet_name: 'str | int | list[IntStrT] | None' = 0, *, header: 'int | Sequence[int] | None' = 0, names: 'list[str] | None' = None, index_col: 'int | Sequence[int] | None' = None, usecols: 'int | str | Sequence[int] | Sequence[str] | Callable[[str], bool] | None' = None, dtype: 'DtypeArg | None' = None, engine: "Literal['xlrd', 'openpyxl', 'odf', 'pyxlsb'] | None" = None, converters: 'dict[str, Callable] | dict[int, Callable] | None' = None, true_values: 'Iterable[Hashable] | None' = None, false_values: 'Iterable[Hashable] | None' = None, skiprows: 'Sequence[int] | int | Callable[[int], object] | None' = None, nrows: 'int | None' = None, na_values=None, keep_default_na: 'bool' = True, na_filter: 'bool' = True, verbose: 'bool' = False, parse_dates: 'list | dict | bool' = False, date_parser: 'Callable | lib.NoDefault' = <no_default>, date_format: 'dict[Hashable, str] | str | None' = None, thousands: 'str | None' = None, decimal: 'str' = '.'
# ...

# %% [markdown]
# Q8. You have a Pandas DataFrame df with columns 'A', 'B', and 'C'. Write a Python function that selects
# all rows where the value in column 'A' is greater than 5 and the value in column 'B' is less than 10. The
# function should return a new DataFrame that contains only the selected rows.

# %%
data = {
    
    'A':[3 , 8  ,6 ,2 , 9],
    'B':[5 , 2 , 9 , 3 , 1],
    'C':[1, 7 , 4, 5 , 2]
    
}

# %%
df = pd.DataFrame(data)

# %%
df = df[(df['A'] > 5) & (df['B'] < 10)]

# %%
df
# Out:
#    A  B  C
# 1  8  2  7
# 2  6  9  4
# 4  9  1  2

# %% [markdown]
# Q9. Given a Pandas DataFrame df with a column 'Values', write a Python function to calculate the mean,
# median, and standard deviation of the values in the 'Values' column.

# %%
df['Values'] = df[['A','B','C']].sum(axis=1)

# %%
df.describe()
# Out:
#               A         B         C     Values
# count  3.000000  3.000000  3.000000   3.000000
# mean   7.666667  4.000000  4.333333  16.000000
# std    1.527525  4.358899  2.516611   3.605551
# min    6.000000  1.000000  2.000000  12.000000
# 25%    7.000000  1.500000  3.000000  14.500000
# 50%    8.000000  2.000000  4.000000  17.000000
# 75%    8.500000  5.500000  5.500000  18.000000
# max    9.000000  9.000000  7.000000  19.000000

# %%
df['Values'].mean()
# Out:
# 16.0

# %%
df['Values'].std()
# Out:
# 3.605551275463989

# %%
df['Values'].median()
# Out:
# 17.0

# %% [markdown]
# Q10. Given a Pandas DataFrame df with a column 'Sales' and a column 'Date', write a Python function to
# create a new column 'MovingAverage' that contains the moving average of the sales for the past 7 days
# for each row in the DataFrame. The moving average should be calculated using a window of size 7 and
# should include the current day.

# %%
df = pd.read_csv("https://raw.githubusercontent.com/wlodarzmar/csvToSqlTable/master/100%20Sales%20Records.csv")

# %%
df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
df['MovingAverage'] = df['Units Sold'].rolling(window=7, min_periods=1).mean()

# %%
df
# Out:
#                                Region                Country        Item Type  \
# 49                 Sub-Saharan Africa             Mauritania  Office Supplies
# 18                               Asia           Turkmenistan        Household
# 86                 Sub-Saharan Africa  Sao Tome and Principe        Beverages
# 37                 Sub-Saharan Africa             The Gambia             Meat
# 31                 Sub-Saharan Africa            South Sudan    Personal Care
# ..                                ...                    ...              ...
# 51                 Sub-Saharan Africa                Lesotho           Fruits
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 21                             Europe               Portugal        Baby Food
# 71       Middle East and North Africa                  Libya           Fruits
# 67  Central America and the Caribbean                 Belize          Clothes
#
# ...

# %% [markdown]
# Q11. You have a Pandas DataFrame df with a column 'Date'. Write a Python function that creates a new
# column 'Weekday' in the DataFrame. The 'Weekday' column should contain the weekday name (e.g.
# Monday, Tuesday) corresponding to each date in the 'Date' column.

# %%
df['Weekday'] = df['Date'].dt.strftime('%A')

# %%
df
# Out:
#                                Region                Country        Item Type  \
# 49                 Sub-Saharan Africa             Mauritania  Office Supplies
# 18                               Asia           Turkmenistan        Household
# 86                 Sub-Saharan Africa  Sao Tome and Principe        Beverages
# 37                 Sub-Saharan Africa             The Gambia             Meat
# 31                 Sub-Saharan Africa            South Sudan    Personal Care
# ..                                ...                    ...              ...
# 51                 Sub-Saharan Africa                Lesotho           Fruits
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 21                             Europe               Portugal        Baby Food
# 71       Middle East and North Africa                  Libya           Fruits
# 67  Central America and the Caribbean                 Belize          Clothes
#
# ...

# %% [markdown]
# Q12. Given a Pandas DataFrame df with a column 'Date' that contains timestamps, write a Python
# function to select all rows where the date is between '2023-01-01' and '2023-01-31'.

# %%
df[(df['Date'] == '2023-01-01') & (df['Date'] == '2023-01-31')]
# Out:
# Empty DataFrame
# Columns: [Region, Country, Item Type, Sales Channel, Order Priority, Order Date, Order ID, Ship Date, Units Sold, Unit Price, Unit Cost, Total Revenue, Total Cost, Total Profit, MovingAverage, Weekday, Date]
# Index: []

# %% [markdown]
# Q13. To use the basic functions of pandas, what is the first and foremost necessary library that needs to
# be imported?

# %%
# pandas library 

import pandas as pd
